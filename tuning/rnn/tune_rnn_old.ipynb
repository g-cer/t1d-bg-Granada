# %% [markdown]
# # RNN Hyperparameter Tuning
#
# This notebook performs systematic hyperparameter tuning for RNN models (LSTM and GRU) using grid search.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Granada-miei/Granada-evaluate-val-set
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Granada-miei/Granada-evaluate-val-set

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.5-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 27.0 MB/s eta 0:00:00
# Downloading alembic-1.16.5-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.4/247.4 kB 27.1 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.5 colorlog-6.9.0 optuna-4.5.0

# %%
import os
import sys
# import warnings

# warnings.filterwarnings("ignore")

# # Add paths for imports
# sys.path.append("training")
# sys.path.append("tuning")

# Import functions from workspace and tune_rnn
from training.split_data import load_splits
from tuning.tune_rnn import (
    set_seeds,
    get_base_lstm_params,
    find_optimal_neurons,
    grid_search_architectures,
    save_tuning_results,
    plot_tuning_results,
)

print("Imports completed successfully!")
# Out:
# Imports completed successfully!

# %%
# Configuration (similar to parse_arguments output)
class Args:
    def __init__(self):
        self.output_dir = "tuning/results"
        self.splits_dir = "training/splits"
        self.seed = 42

args = Args()

# Ensure output directory exists
if not os.path.exists(args.output_dir):
    os.makedirs(args.output_dir)

print("Configuration:")
print(f"  Output directory: {args.output_dir}")
print(f"  Splits directory: {args.splits_dir}")
print(f"  Random seed: {args.seed}")
# Out:
# Configuration:
#   Output directory: tuning/results
#   Splits directory: training/splits
#   Random seed: 42

# %% [markdown]
# ## Load Data Splits
#
# Load the preprocessed data splits for training and validation.

# %%
# Load data splits using workspace function
print("Loading pre-prepared data splits...")
train_set, val_set, test_set, X_cols, y_cols = load_splits(args.splits_dir)

print(f"Train set size: {len(train_set)}")
print(f"Validation set size: {len(val_set)}")
print(f"Test set size: {len(test_set)}")
print(f"Features: {len(X_cols)}")
print(f"Target: {y_cols}")

print(f"\nFeature columns: {X_cols}")
# Out:
# Loading pre-prepared data splits...
# Train set size: 14058224
# Validation set size: 1861178
# Test set size: 3945594
# Features: 8
# Target: ['lead30']
#
# Feature columns: ['lag105', 'lag90', 'lag75', 'lag60', 'lag45', 'lag30', 'lag15', 'lag0']

# %% [markdown]
# ## Systematic RNN Hyperparameter Tuning
#
# Perform the complete tuning process with two phases:
# 1. Find optimal number of neurons
# 2. Grid search over architectures and model types

# %%
# Initialize tuning process
print("=" * 60)
print("SYSTEMATIC RNN HYPERPARAMETER TUNING")
print("=" * 60)

# Set initial seed for reproducibility
set_seeds(args.seed)

# Get base parameters for LSTM/GRU training
base_params = get_base_lstm_params()

print("\nBase training parameters:")
for key, value in base_params.items():
    print(f"  {key}: {value}")
# Out:
# ============================================================
# SYSTEMATIC RNN HYPERPARAMETER TUNING
# ============================================================
#
# Base training parameters:
#   batch_size: 4096
#   epochs: 100
#   learning_rate: 0.01
#   early_stopping_patience: 5
#   lr_scheduler_patience: 3
#   lr_reduction_factor: 0.1
#   min_learning_rate: 1e-06
#   monitor: val_loss
#   min_delta: 1e-05

# %%
# Phase 1: Find optimal number of neurons using baseline LSTM architecture
best_neurons, neuron_results = find_optimal_neurons(
    train_set, val_set, X_cols, y_cols, base_params, args.seed
)

print(f"\n🎯 Phase 1 completed: Best neuron count = {best_neurons}")
# Out:
# ============================================================
# PHASE 1: Finding Optimal Number of Neurons
# ============================================================
# Testing neuron configurations with baseline architecture (2 layers, 0.2 dropout)
#
# Configuration: LSTM, hidden_size=50, num_layers=2, dropout=0.2
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 61s 15ms/step - loss: 0.0074 - mae: 0.0857 - val_loss: 0.0059 - val_mae: 0.0776 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 58s 15ms/step - loss: 0.0060 - mae: 0.0782 - val_loss: 0.0058 - val_mae: 0.0771 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 58s 16ms/step - loss: 0.0059 - mae: 0.0777 - val_loss: 0.0057 - val_mae: 0.0761 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 59s 16ms/step - loss: 0.0059 - mae: 0.0775 - val_loss: 0.0056 - val_mae: 0.0760 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 59s 16ms/step - loss: 0.0059 - mae: 0.0773 - val_loss: 0.0058 - val_mae: 0.0778 - learning_rate: 0.0100
# Epoch 6/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0059 - mae: 0.0771
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 59s 16ms/step - loss: 0.0059 - mae: 0.0771 - val_loss: 0.0066 - val_mae: 0.0843 - learning_rate: 0.0100
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 59s 16ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0073 - val_mae: 0.0886 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 59s 16ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0076 - val_mae: 0.0906 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0058 - mae: 0.0765
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 59s 16ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0079 - val_mae: 0.0924 - learning_rate: 1.0000e-03
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# Hidden size 50: MAE = 13.6695
#
# Configuration: LSTM, hidden_size=64, num_layers=2, dropout=0.2
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 62s 16ms/step - loss: 0.0070 - mae: 0.0840 - val_loss: 0.0058 - val_mae: 0.0772 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - loss: 0.0060 - mae: 0.0779 - val_loss: 0.0058 - val_mae: 0.0768 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - loss: 0.0059 - mae: 0.0775 - val_loss: 0.0057 - val_mae: 0.0758 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - loss: 0.0059 - mae: 0.0773 - val_loss: 0.0057 - val_mae: 0.0762 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - loss: 0.0059 - mae: 0.0771 - val_loss: 0.0058 - val_mae: 0.0787 - learning_rate: 0.0100
# Epoch 6/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0059 - mae: 0.0770
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - loss: 0.0059 - mae: 0.0771 - val_loss: 0.0061 - val_mae: 0.0828 - learning_rate: 0.0100
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0060 - val_mae: 0.0820 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0061 - val_mae: 0.0833 - learning_rate: 1.0000e-03
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Hidden size 64: MAE = 13.6326
#
# Configuration: LSTM, hidden_size=75, num_layers=2, dropout=0.2
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 66s 17ms/step - loss: 0.0068 - mae: 0.0828 - val_loss: 0.0058 - val_mae: 0.0778 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 64s 17ms/step - loss: 0.0059 - mae: 0.0777 - val_loss: 0.0058 - val_mae: 0.0771 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0059 - mae: 0.0774 - val_loss: 0.0057 - val_mae: 0.0758 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0059 - mae: 0.0772 - val_loss: 0.0057 - val_mae: 0.0760 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0059 - mae: 0.0771 - val_loss: 0.0057 - val_mae: 0.0762 - learning_rate: 0.0100
# Epoch 6/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0059 - mae: 0.0770
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0059 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0774 - learning_rate: 0.0100
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0058 - mae: 0.0765
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0058 - mae: 0.0765
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 65s 17ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Hidden size 75: MAE = 13.5551
#
# Configuration: LSTM, hidden_size=86, num_layers=2, dropout=0.2
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 69s 18ms/step - loss: 0.0068 - mae: 0.0830 - val_loss: 0.0059 - val_mae: 0.0779 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0059 - mae: 0.0777 - val_loss: 0.0058 - val_mae: 0.0771 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0059 - mae: 0.0774 - val_loss: 0.0057 - val_mae: 0.0760 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0059 - mae: 0.0772 - val_loss: 0.0057 - val_mae: 0.0760 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0059 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0766 - learning_rate: 0.0100
# Epoch 6/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0770
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0771 - learning_rate: 0.0100
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0758 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0765
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0758 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0755 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0755 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0755 - learning_rate: 1.0000e-04
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0755 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0755 - learning_rate: 1.0000e-05
# Epoch 15/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 68s 18ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0755 - learning_rate: 1.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Hidden size 86: MAE = 13.5764
#
# Configuration: LSTM, hidden_size=100, num_layers=2, dropout=0.2
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0067 - mae: 0.0821 - val_loss: 0.0058 - val_mae: 0.0780 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0059 - mae: 0.0776 - val_loss: 0.0057 - val_mae: 0.0771 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0059 - mae: 0.0773 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0059 - mae: 0.0771 - val_loss: 0.0056 - val_mae: 0.0760 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 20ms/step - loss: 0.0058 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0767 - learning_rate: 0.0100
# Epoch 6/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0058 - mae: 0.0769
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 20ms/step - loss: 0.0058 - mae: 0.0769 - val_loss: 0.0057 - val_mae: 0.0770 - learning_rate: 0.0100
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 20ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0058 - mae: 0.0765
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 73s 19ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Hidden size 100: MAE = 13.5485
#
# Configuration: LSTM, hidden_size=128, num_layers=2, dropout=0.2
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 80s 21ms/step - loss: 0.0067 - mae: 0.0822 - val_loss: 0.0059 - val_mae: 0.0786 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0776 - val_loss: 0.0057 - val_mae: 0.0767 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0772 - val_loss: 0.0057 - val_mae: 0.0757 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0761 - learning_rate: 0.0100
# Epoch 5/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - mae: 0.0769
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0769 - val_loss: 0.0057 - val_mae: 0.0768 - learning_rate: 0.0100
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 80s 21ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 80s 21ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 80s 21ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 80s 21ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - mae: 0.0763
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - mae: 0.0763
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Hidden size 128: MAE = 13.5450
#
# Best neuron configuration: 128 neurons (MAE: 13.5450)
#
# 🎯 Phase 1 completed: Best neuron count = 128

# %%
# Phase 2: Grid search over architectures and model types with optimal neurons
best_config, grid_search_results = grid_search_architectures(
    train_set, val_set, X_cols, y_cols, base_params, best_neurons, args.seed
)

print(f"\n🎯 Phase 2 completed: Best configuration found")
# Out:
# ============================================================
# PHASE 2: Grid Search - Architecture Configurations
# ============================================================
# Testing configurations:
#   1-layer models: ['LSTM', 'GRU'] x dropout=[0.0] = 2 configs
#   2-layer models: ['LSTM', 'GRU'] x dropout=[0.0, 0.1, 0.2, 0.4] = 8 configs
#   Total configurations: 10
#
# [1/10] Testing: LSTM, 1 layer(s), dropout 0.0
#
# Configuration: LSTM, hidden_size=128, num_layers=1, dropout=0.0
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 0.0067 - mae: 0.0820 - val_loss: 0.0058 - val_mae: 0.0780 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0059 - mae: 0.0775 - val_loss: 0.0057 - val_mae: 0.0770 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0059 - mae: 0.0772 - val_loss: 0.0057 - val_mae: 0.0768 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0765 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0769 - val_loss: 0.0057 - val_mae: 0.0764 - learning_rate: 0.0100
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0768 - val_loss: 0.0057 - val_mae: 0.0768 - learning_rate: 0.0100
# Epoch 7/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - mae: 0.0767
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0057 - val_mae: 0.0769 - learning_rate: 0.0100
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 11/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-04
# Epoch 13/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-04
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# ✅ LSTM 1-layer dropout 0.0: MAE = 13.6025
#
# [2/10] Testing: GRU, 1 layer(s), dropout 0.0
#
# Configuration: GRU, hidden_size=128, num_layers=1, dropout=0.0
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 41s 10ms/step - loss: 0.0065 - mae: 0.0809 - val_loss: 0.0058 - val_mae: 0.0776 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0060 - mae: 0.0779 - val_loss: 0.0057 - val_mae: 0.0767 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0059 - mae: 0.0772 - val_loss: 0.0057 - val_mae: 0.0775 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0059 - mae: 0.0771 - val_loss: 0.0057 - val_mae: 0.0770 - learning_rate: 0.0100
# Epoch 5/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - mae: 0.0770
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0058 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0766 - learning_rate: 0.0100
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0056 - val_mae: 0.0759 - learning_rate: 1.0000e-03
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0759 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - mae: 0.0765
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0759 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-04
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-05
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 39s 10ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.
# ✅ GRU 1-layer dropout 0.0: MAE = 13.6016
#
# [3/10] Testing: LSTM, 2 layer(s), dropout 0.0
#
# Configuration: LSTM, hidden_size=128, num_layers=2, dropout=0.0
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0070 - mae: 0.0826 - val_loss: 0.0057 - val_mae: 0.0760 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0757 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0057 - val_mae: 0.0765 - learning_rate: 0.0100
# Epoch 4/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0766
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0056 - val_mae: 0.0762 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0758 - learning_rate: 1.0000e-03
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0761 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0761 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0761
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0761 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# ✅ LSTM 2-layer dropout 0.0: MAE = 13.6227
#
# [4/10] Testing: LSTM, 2 layer(s), dropout 0.1
#
# Configuration: LSTM, hidden_size=128, num_layers=2, dropout=0.1
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 81s 21ms/step - loss: 0.0067 - mae: 0.0817 - val_loss: 0.0058 - val_mae: 0.0778 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0774 - val_loss: 0.0057 - val_mae: 0.0761 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0771 - val_loss: 0.0057 - val_mae: 0.0757 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0769 - val_loss: 0.0057 - val_mae: 0.0765 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0768 - val_loss: 0.0057 - val_mae: 0.0772 - learning_rate: 0.0100
# Epoch 6/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - mae: 0.0767
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0057 - val_mae: 0.0770 - learning_rate: 0.0100
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - mae: 0.0763
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - mae: 0.0762
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 80s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - mae: 0.0762
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# ✅ LSTM 2-layer dropout 0.1: MAE = 13.5441
#
# [5/10] Testing: LSTM, 2 layer(s), dropout 0.2
#
# Configuration: LSTM, hidden_size=128, num_layers=2, dropout=0.2
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0067 - mae: 0.0822 - val_loss: 0.0059 - val_mae: 0.0786 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0059 - mae: 0.0776 - val_loss: 0.0057 - val_mae: 0.0767 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0059 - mae: 0.0772 - val_loss: 0.0057 - val_mae: 0.0757 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0059 - mae: 0.0770 - val_loss: 0.0057 - val_mae: 0.0761 - learning_rate: 0.0100
# Epoch 5/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0769
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0769 - val_loss: 0.0057 - val_mae: 0.0768 - learning_rate: 0.0100
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 9: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0763
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0763
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 21ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# ✅ LSTM 2-layer dropout 0.2: MAE = 13.5450
#
# [6/10] Testing: LSTM, 2 layer(s), dropout 0.4
#
# Configuration: LSTM, hidden_size=128, num_layers=2, dropout=0.4
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 80s 21ms/step - loss: 0.0069 - mae: 0.0833 - val_loss: 0.0058 - val_mae: 0.0780 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0060 - mae: 0.0781 - val_loss: 0.0058 - val_mae: 0.0769 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0777 - val_loss: 0.0057 - val_mae: 0.0754 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0775 - val_loss: 0.0057 - val_mae: 0.0758 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0773 - val_loss: 0.0057 - val_mae: 0.0766 - learning_rate: 0.0100
# Epoch 6/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0059 - mae: 0.0772
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0059 - mae: 0.0772 - val_loss: 0.0057 - val_mae: 0.0771 - learning_rate: 0.0100
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0059 - val_mae: 0.0787 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 79s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0063 - val_mae: 0.0815 - learning_rate: 1.0000e-03
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# ✅ LSTM 2-layer dropout 0.4: MAE = 13.5598
#
# [7/10] Testing: GRU, 2 layer(s), dropout 0.0
#
# Configuration: GRU, hidden_size=128, num_layers=2, dropout=0.0
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0069 - mae: 0.0819 - val_loss: 0.0058 - val_mae: 0.0776 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 74s 20ms/step - loss: 0.0059 - mae: 0.0771 - val_loss: 0.0058 - val_mae: 0.0778 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0769 - val_loss: 0.0057 - val_mae: 0.0763 - learning_rate: 0.0100
# Epoch 4/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0057 - val_mae: 0.0759 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0057 - val_mae: 0.0762 - learning_rate: 0.0100
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0057 - val_mae: 0.0768 - learning_rate: 0.0100
# Epoch 7/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0765
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0057 - val_mae: 0.0768 - learning_rate: 0.0100
# Epoch 8/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0761 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0761 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 10/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0057 - mae: 0.0761
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0761 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 11/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0760 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0760 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 13/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0057 - mae: 0.0760
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0760 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 14/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0760 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 15/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0760 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 16/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0057 - mae: 0.0760
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0057 - mae: 0.0760 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.
# ✅ GRU 2-layer dropout 0.0: MAE = 13.5428
#
# [8/10] Testing: GRU, 2 layer(s), dropout 0.1
#
# Configuration: GRU, hidden_size=128, num_layers=2, dropout=0.1
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 76s 20ms/step - loss: 0.0068 - mae: 0.0819 - val_loss: 0.0058 - val_mae: 0.0778 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0059 - mae: 0.0775 - val_loss: 0.0058 - val_mae: 0.0767 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0059 - mae: 0.0773 - val_loss: 0.0059 - val_mae: 0.0781 - learning_rate: 0.0100
# Epoch 4/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0059 - mae: 0.0772
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0059 - mae: 0.0772 - val_loss: 0.0058 - val_mae: 0.0768 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0763 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0762
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0762
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0762 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.
# ✅ GRU 2-layer dropout 0.1: MAE = 13.5458
#
# [9/10] Testing: GRU, 2 layer(s), dropout 0.2
#
# Configuration: GRU, hidden_size=128, num_layers=2, dropout=0.2
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 76s 20ms/step - loss: 0.0069 - mae: 0.0825 - val_loss: 0.0058 - val_mae: 0.0773 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0059 - mae: 0.0778 - val_loss: 0.0058 - val_mae: 0.0764 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0059 - mae: 0.0776 - val_loss: 0.0059 - val_mae: 0.0777 - learning_rate: 0.0100
# Epoch 4/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0059 - mae: 0.0774
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0059 - mae: 0.0774 - val_loss: 0.0058 - val_mae: 0.0771 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0766 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0765
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0765 - val_loss: 0.0056 - val_mae: 0.0756 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0764
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - loss: 0.0058 - mae: 0.0764 - val_loss: 0.0056 - val_mae: 0.0753 - learning_rate: 1.0000e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.
# ✅ GRU 2-layer dropout 0.2: MAE = 13.5464
#
# [10/10] Testing: GRU, 2 layer(s), dropout 0.4
#
# Configuration: GRU, hidden_size=128, num_layers=2, dropout=0.4
# Epoch 1/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 78s 20ms/step - loss: 0.0070 - mae: 0.0836 - val_loss: 0.0058 - val_mae: 0.0774 - learning_rate: 0.0100
# Epoch 2/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 76s 20ms/step - loss: 0.0060 - mae: 0.0785 - val_loss: 0.0057 - val_mae: 0.0766 - learning_rate: 0.0100
# Epoch 3/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0060 - mae: 0.0782 - val_loss: 0.0058 - val_mae: 0.0770 - learning_rate: 0.0100
# Epoch 4/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0060 - mae: 0.0780
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0060 - mae: 0.0780 - val_loss: 0.0058 - val_mae: 0.0769 - learning_rate: 0.0100
# Epoch 5/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0059 - mae: 0.0770 - val_loss: 0.0056 - val_mae: 0.0758 - learning_rate: 1.0000e-03
# Epoch 6/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0770 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 7/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0769 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 8/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0769
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0769 - val_loss: 0.0056 - val_mae: 0.0757 - learning_rate: 1.0000e-03
# Epoch 9/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0056 - val_mae: 0.0754 - learning_rate: 1.0000e-04
# Epoch 10/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0056 - val_mae: 0.0754 - learning_rate: 1.0000e-04
# Epoch 11/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0767
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999019782991e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0056 - val_mae: 0.0754 - learning_rate: 1.0000e-04
# Epoch 12/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0056 - val_mae: 0.0754 - learning_rate: 1.0000e-05
# Epoch 13/100
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0056 - val_mae: 0.0754 - learning_rate: 1.0000e-05
# Epoch 14/100
# 3329/3433 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0058 - mae: 0.0767
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1e-06.
# 3433/3433 ━━━━━━━━━━━━━━━━━━━━ 77s 21ms/step - loss: 0.0058 - mae: 0.0767 - val_loss: 0.0056 - val_mae: 0.0754 - learning_rate: 1.0000e-05
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.
# ✅ GRU 2-layer dropout 0.4: MAE = 13.5679
#
# 🏆 Best overall configuration:
#   Model type: GRU
#   Architecture: GRU-2layer
#   Hidden size: 128
#   Layers: 2
#   Dropout: 0.0
#   MAE: 13.5428
#
# 🎯 Phase 2 completed: Best configuration found

# %% [markdown]
# ## Save Results and Create Visualizations
#
# Save the tuning results to CSV files and create visualization plots.

# %%
# Save tuning results to CSV files
save_tuning_results(neuron_results, grid_search_results, args.output_dir)

# Create and save visualization plots
plot_tuning_results(neuron_results, grid_search_results, args.output_dir)

print("\n📊 Results and plots saved successfully!")
# Out:
# Results saved to tuning/results
#
# 📊 Results and plots saved successfully!

# %% [markdown]
# ## Final Summary
#
# Display the complete tuning summary with best configuration details.

# %%
# Display final summary (same as main function output)
print(f"\n{'='*60}")
print(f"RNN TUNING SUMMARY")
print(f"{'='*60}")

print(f"Best configuration MAE: {best_config['mae']:.4f}")
print(f"\nBest configuration details:")
print(f"  Model type: {best_config['model_type']}")
print(f"  Architecture: {best_config['architecture']}")
print(f"  Hidden size: {best_config['hidden_size']}")
print(f"  Layers: {best_config['num_layers']}")
print(f"  Dropout: {best_config['dropout']}")

print(f"\n📁 Output files generated:")
print(f"  - {args.output_dir}/rnn_neuron_tuning_results.csv")
print(f"  - {args.output_dir}/rnn_grid_search_results.csv")
print(f"  - Visualization plots in {args.output_dir}")

print(f"\n✅ RNN hyperparameter tuning completed successfully!")
# Out:
# ============================================================
# RNN TUNING SUMMARY
# ============================================================
# Best configuration MAE: 13.5428
#
# Best configuration details:
#   Model type: GRU
#   Architecture: GRU-2layer
#   Hidden size: 128
#   Layers: 2
#   Dropout: 0.0
#
# 📁 Output files generated:
#   - tuning/results/rnn_neuron_tuning_results.csv
#   - tuning/results/rnn_grid_search_results.csv
#   - Visualization plots in tuning/results
#
# ✅ RNN hyperparameter tuning completed successfully!

# %% [markdown]
# ## View Results Summary
#
# Display a quick summary of the tuning results.

# %%
import pandas as pd

# Display neuron tuning results
print("\n📊 NEURON TUNING RESULTS:")
neuron_df = pd.DataFrame(neuron_results)
print(neuron_df.sort_values('mae'))

# Display top 5 grid search results
print("\n📊 TOP 5 GRID SEARCH RESULTS:")
grid_search_df = pd.DataFrame(grid_search_results)
top_5 = grid_search_df.nsmallest(5, 'mae')
print(top_5[['model_type', 'num_layers', 'dropout', 'mae']])
# Out:
# 📊 NEURON TUNING RESULTS:
#    hidden_size        mae
# 5          128  13.545000
# 4          100  13.548456
# 2           75  13.555089
# 3           86  13.576434
# 1           64  13.632625
# 0           50  13.669458
#
# 📊 TOP 5 GRID SEARCH RESULTS:
#   model_type  num_layers  dropout        mae
# 6        GRU           2      0.0  13.542810
# 3       LSTM           2      0.1  13.544109
# 4       LSTM           2      0.2  13.545000
# 7        GRU           2      0.1  13.545751
# 8        GRU           2      0.2  13.546441

# %%
from google.colab import runtime
runtime.unassign()
