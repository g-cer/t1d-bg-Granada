# %% [markdown]
# # Machine Learning Models Hyperparameter Tuning
# This notebook performs hyperparameter tuning for XGBoost and LightGBM models using Optuna optimization.

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Granada-miei/Granada-evaluate-val-set
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Granada-miei/Granada-evaluate-val-set

# %%
# %pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.16.5-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 13.7 MB/s eta 0:00:00
# Downloading alembic-1.16.5-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.4/247.4 kB 27.2 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.16.5 colorlog-6.9.0 optuna-4.5.0

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import lightgbm as lgb
# import warnings
# warnings.filterwarnings('ignore')

# Add tuning directory to path
sys.path.insert(0, '/content/drive/MyDrive/Granada-miei/Granada-evaluate-val-set/tuning')

from utils_tuning import (
    load_splits,
    plot_optimization_history,
    train_final_model_and_evaluate,
)
from tune_xgb import tune_xgb, get_base_xgb_params
from tune_lgb import tune_lgb, get_base_lgb_params

# %%
# Configuration
config = {
    'output_dir': 'tuning/results',
    'splits_dir': 'training/splits',
    'n_trials': 40,
    'timeout': 3600,  # 1 hour
    'seed': 42,
    'enable_gpu': True,
    'models_to_tune': ['lgb']  # Change this to tune specific models
}

# Create output directory
os.makedirs(config['output_dir'], exist_ok=True)
np.random.seed(config['seed'])

print("Configuration:")
for key, value in config.items():
    print(f"  {key}: {value}")
# Out:
# Configuration:
#   output_dir: tuning/results
#   splits_dir: training/splits
#   n_trials: 40
#   timeout: 3600
#   seed: 42
#   enable_gpu: True
#   models_to_tune: ['lgb']

# %% [markdown]
# ## Load Data Splits
# Load the pre-prepared data splits used for training and validation.

# %%
print("Loading data splits...")
train_set, val_set, test_set, X_cols, y_cols = load_splits(config['splits_dir'])

print(f"Data loaded successfully:")
print(f"  Train set: {train_set.shape}")
print(f"  Validation set: {val_set.shape}")
print(f"  Test set: {test_set.shape}")
print(f"  Features: {len(X_cols)}")
print(f"  Target: {y_cols}")
print(f"  Unique patients in train: {train_set['Patient_ID'].nunique()}")
print(f"  Unique patients in val: {val_set['Patient_ID'].nunique()}")
print(f"  Unique patients in test: {test_set['Patient_ID'].nunique()}")
# Out:
# Loading data splits...
# Data loaded successfully:
#   Train set: (14058224, 12)
#   Validation set: (1861178, 12)
#   Test set: (3945594, 12)
#   Features: 8
#   Target: ['lead30']
#   Unique patients in train: 483
#   Unique patients in val: 68
#   Unique patients in test: 138

# %% [markdown]
# ## Hyperparameter Tuning
# Perform Optuna-based hyperparameter optimization for each selected model.

# %%
def create_args_object(model_name, config):
    """Create an arguments object similar to argparse for compatibility"""
    class Args:
        def __init__(self):
            self.model = model_name
            self.output_dir = config['output_dir']
            self.n_trials = config['n_trials']
            self.timeout = config['timeout']
            self.seed = config['seed']
            self.enable_gpu = config['enable_gpu']
            self.splits_dir = config['splits_dir']

    return Args()

# Store results for comparison
tuning_results = {}

for model_name in config['models_to_tune']:
    print(f"\n{'='*60}")
    print(f"{model_name.upper()} HYPERPARAMETER TUNING")
    print(f"{'='*60}")
    print(f"Method: Optuna Bayesian Optimization")
    print(f"Trials: {config['n_trials']}")
    print(f"Timeout: {config['timeout']}s")
    print(f"GPU enabled: {config['enable_gpu']}")
    print(f"Evaluation metric: Patient-based MAE")
    print(f"{'='*60}")

    # Create args object for compatibility
    args = create_args_object(model_name, config)

    # Run tuning based on model type
    if model_name == 'xgb':
        study, baseline_mae = tune_xgb(train_set, val_set, X_cols, y_cols, args)
        base_params = get_base_xgb_params(config['seed'], config['enable_gpu'])
        model_class = xgb.XGBRegressor
    elif model_name == 'lgb':
        study, baseline_mae = tune_lgb(train_set, val_set, X_cols, y_cols, args)
        base_params = get_base_lgb_params(config['seed'], config['enable_gpu'])
        model_class = lgb.LGBMRegressor

    # Store results
    tuning_results[model_name] = {
        'study': study,
        'baseline_mae': baseline_mae,
        'best_mae': study.best_value,
        'best_params': study.best_params,
        'base_params': base_params,
        'model_class': model_class
    }

    # Print summary
    improvement = baseline_mae - study.best_value
    improvement_pct = (improvement / baseline_mae * 100)

    print(f"\n{'-'*40}")
    print(f"TUNING SUMMARY - {model_name.upper()}")
    print(f"{'-'*40}")
    print(f"Baseline MAE: {baseline_mae:.4f}")
    print(f"Best MAE: {study.best_value:.4f}")
    print(f"Improvement: {improvement:.4f} ({improvement_pct:.2f}%)")
    print(f"Best parameters: {study.best_params}")
# Out:
# ============================================================
# LGB HYPERPARAMETER TUNING
# ============================================================
# Method: Optuna Bayesian Optimization
# Trials: 40
# Timeout: 3600s
# GPU enabled: True
# Evaluation metric: Patient-based MAE
# ============================================================
# ============================================================
# LightGBM Hyperparameter Tuning
# ============================================================
# Evaluating baseline LightGBM model...
# [I 2025-08-27 18:38:45,935] A new study created in memory with name: lgb_glucose_prediction
# LightGBM baseline patient-based MAE: 14.2872
# Starting Optuna hyperparameter optimization for LGB...
#   0%|          | 0/40 [00:00<?, ?it/s]
# [I 2025-08-27 18:39:07,105] Trial 0 finished with value: 14.501864767753599 and parameters: {'num_leaves': 118, 'max_depth': 12, 'min_child_samples': 75, 'min_child_weight': 0.24810409748678125, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'subsample_freq': 1, 'reg_alpha': 0.6245760287469893, 'reg_lambda': 0.002570603566117598, 'learning_rate': 0.11114989443094977, 'n_estimators': 55, 'min_split_gain': 0.9699098521619943, 'min_data_in_leaf': 43}. Best is trial 0 with value: 14.501864767753599.
# [I 2025-08-27 18:39:47,423] Trial 1 finished with value: 16.258829955195075 and parameters: {'num_leaves': 71, 'max_depth': 4, 'min_child_samples': 22, 'min_child_weight': 0.016480446427978974, 'subsample': 0.8099025726528951, 'colsample_bytree': 0.7727780074568463, 'subsample_freq': 3, 'reg_alpha': 0.0032112643094417484, 'reg_lambda': 1.8007140198129195e-07, 'learning_rate': 0.027010527749605478, 'n_estimators': 141, 'min_split_gain': 0.45606998421703593, 'min_data_in_leaf': 41}. Best is trial 0 with value: 14.501864767753599.
# [I 2025-08-27 18:40:21,454] Trial 2 finished with value: 14.177199984998717 and parameters: {'num_leaves': 68, 'max_depth': 8, 'min_child_samples': 61, 'min_child_weight': 0.0015339162591163618, 'subsample': 0.8430179407605753, 'colsample_bytree': 0.6682096494749166, 'subsample_freq': 1, 'reg_alpha': 3.4671276804481113, 'reg_lambda': 4.905556676028774, 'learning_rate': 0.1563510870813346, 'n_estimators': 126, 'min_split_gain': 0.09767211400638387, 'min_data_in_leaf': 36}. Best is trial 2 with value: 14.177199984998717.
# [I 2025-08-27 18:40:48,265] Trial 3 finished with value: 15.447289135250102 and parameters: {'num_leaves': 138, 'max_depth': 4, 'min_child_samples': 52, 'min_child_weight': 0.0013726318898045872, 'subsample': 0.9637281608315128, 'colsample_bytree': 0.7035119926400067, 'subsample_freq': 5, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129, 'learning_rate': 0.06420330336297862, 'n_estimators': 96, 'min_split_gain': 0.9695846277645586, 'min_data_in_leaf': 40}. Best is trial 2 with value: 14.177199984998717.
# [I 2025-08-27 18:42:33,098] Trial 4 finished with value: 14.352109204212084 and parameters: {'num_leaves': 283, 'max_depth': 11, 'min_child_samples': 62, 'min_child_weight': 4.869640941520899, 'subsample': 0.6353970008207678, 'colsample_bytree': 0.6783931449676581, 'subsample_freq': 1, 'reg_alpha': 8.471746987003668e-06, 'reg_lambda': 3.148441347423712e-05, 'learning_rate': 0.02516607127550297, 'n_estimators': 258, 'min_split_gain': 0.3567533266935893, 'min_data_in_leaf': 17}. Best is trial 2 with value: 14.177199984998717.
# [I 2025-08-27 18:43:47,424] Trial 5 finished with value: 14.381580191568013 and parameters: {'num_leaves': 167, 'max_depth': 4, 'min_child_samples': 82, 'min_child_weight': 0.0019870215385428634, 'subsample': 0.9947547746402069, 'colsample_bytree': 0.908897907718663, 'subsample_freq': 2, 'reg_alpha': 1.1212412169964432e-08, 'reg_lambda': 0.2183498289760726, 'learning_rate': 0.11069143219393454, 'n_estimators': 232, 'min_split_gain': 0.7712703466859457, 'min_data_in_leaf': 8}. Best is trial 2 with value: 14.177199984998717.
# [I 2025-08-27 18:44:54,000] Trial 6 finished with value: 14.6882737654261 and parameters: {'num_leaves': 114, 'max_depth': 4, 'min_child_samples': 87, 'min_child_weight': 0.3113095956122124, 'subsample': 0.7323592099410596, 'colsample_bytree': 0.6254233401144095, 'subsample_freq': 3, 'reg_alpha': 8.445977074223802e-06, 'reg_lambda': 0.036851536911881845, 'learning_rate': 0.0874479618932312, 'n_estimators': 272, 'min_split_gain': 0.4722149251619493, 'min_data_in_leaf': 10}. Best is trial 2 with value: 14.177199984998717.
# [I 2025-08-27 18:46:53,542] Trial 7 finished with value: 16.270736245868598 and parameters: {'num_leaves': 217, 'max_depth': 10, 'min_child_samples': 58, 'min_child_weight': 1.2130221181165162, 'subsample': 0.7975182385457563, 'colsample_bytree': 0.8090931317527976, 'subsample_freq': 3, 'reg_alpha': 1.6934490731313353e-08, 'reg_lambda': 9.354548757337708e-08, 'learning_rate': 0.011128194768838964, 'n_estimators': 209, 'min_split_gain': 0.3143559810763267, 'min_data_in_leaf': 28}. Best is trial 2 with value: 14.177199984998717.
# [I 2025-08-27 18:47:49,392] Trial 8 finished with value: 14.349070241855795 and parameters: {'num_leaves': 274, 'max_depth': 5, 'min_child_samples': 44, 'min_child_weight': 1.0524574681335637, 'subsample': 0.6915192661966489, 'colsample_bytree': 0.6307919639315172, 'subsample_freq': 3, 'reg_alpha': 2.824825241715838e-07, 'reg_lambda': 2.3295866619309256, 'learning_rate': 0.156203869845265, 'n_estimators': 208, 'min_split_gain': 0.8714605901877177, 'min_data_in_leaf': 41}. Best is trial 2 with value: 14.177199984998717.
# [I 2025-08-27 18:48:56,648] Trial 9 finished with value: 13.876688119185703 and parameters: {'num_leaves': 64, 'max_depth': 11, 'min_child_samples': 56, 'min_child_weight': 1.6973078532467012, 'subsample': 0.9584365199693973, 'colsample_bytree': 0.7272013899887455, 'subsample_freq': 1, 'reg_alpha': 1.1256839212661599e-06, 'reg_lambda': 6.98184330520185e-05, 'learning_rate': 0.16155001304356414, 'n_estimators': 266, 'min_split_gain': 0.006952130531190703, 'min_data_in_leaf': 28}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:50:08,967] Trial 10 finished with value: 13.964789231980586 and parameters: {'num_leaves': 16, 'max_depth': 8, 'min_child_samples': 5, 'min_child_weight': 0.0364301368074631, 'subsample': 0.9122127063264295, 'colsample_bytree': 0.9630659181130071, 'subsample_freq': 7, 'reg_alpha': 0.00413763088103683, 'reg_lambda': 7.551072925546471e-06, 'learning_rate': 0.2923075181403218, 'n_estimators': 299, 'min_split_gain': 0.00869368030950269, 'min_data_in_leaf': 26}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:51:21,050] Trial 11 finished with value: 13.950709880972397 and parameters: {'num_leaves': 18, 'max_depth': 8, 'min_child_samples': 6, 'min_child_weight': 0.0436802156999803, 'subsample': 0.9094745799135293, 'colsample_bytree': 0.97526603101889, 'subsample_freq': 7, 'reg_alpha': 0.0026519614761839013, 'reg_lambda': 7.868729181011707e-06, 'learning_rate': 0.2971209283602247, 'n_estimators': 290, 'min_split_gain': 0.027340048919821423, 'min_data_in_leaf': 25}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:52:22,378] Trial 12 finished with value: 14.097725547473388 and parameters: {'num_leaves': 10, 'max_depth': 9, 'min_child_samples': 31, 'min_child_weight': 9.1985554366307, 'subsample': 0.8947284366720102, 'colsample_bytree': 0.8314825173681082, 'subsample_freq': 7, 'reg_alpha': 0.000998681825577111, 'reg_lambda': 4.72334668260679e-06, 'learning_rate': 0.29893631712640445, 'n_estimators': 297, 'min_split_gain': 0.17872432451031076, 'min_data_in_leaf': 26}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:53:39,405] Trial 13 finished with value: 13.94620634201681 and parameters: {'num_leaves': 63, 'max_depth': 6, 'min_child_samples': 8, 'min_child_weight': 0.01601020250310394, 'subsample': 0.9284011759510725, 'colsample_bytree': 0.7432589520258098, 'subsample_freq': 5, 'reg_alpha': 0.12012982541970996, 'reg_lambda': 1.2208559671814701e-08, 'learning_rate': 0.21040232511535578, 'n_estimators': 247, 'min_split_gain': 0.18818213331382344, 'min_data_in_leaf': 50}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:54:53,741] Trial 14 finished with value: 13.989481469389276 and parameters: {'num_leaves': 64, 'max_depth': 6, 'min_child_samples': 35, 'min_child_weight': 0.008567025579177196, 'subsample': 0.9569601426147203, 'colsample_bytree': 0.7463169843337756, 'subsample_freq': 5, 'reg_alpha': 0.05740835784199986, 'reg_lambda': 1.0161248497631511e-08, 'learning_rate': 0.17224495220753938, 'n_estimators': 237, 'min_split_gain': 0.21328333563112212, 'min_data_in_leaf': 49}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:55:56,544] Trial 15 finished with value: 14.499187807175002 and parameters: {'num_leaves': 178, 'max_depth': 6, 'min_child_samples': 24, 'min_child_weight': 0.14467053264901533, 'subsample': 0.8614838463376575, 'colsample_bytree': 0.8601529460347925, 'subsample_freq': 5, 'reg_alpha': 6.872583021155946e-05, 'reg_lambda': 3.0563913645308207e-07, 'learning_rate': 0.036046969689776935, 'n_estimators': 183, 'min_split_gain': 0.6041585495011993, 'min_data_in_leaf': 49}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:57:14,753] Trial 16 finished with value: 13.951458794339759 and parameters: {'num_leaves': 91, 'max_depth': 6, 'min_child_samples': 43, 'min_child_weight': 1.535030112998986, 'subsample': 0.9931433394672755, 'colsample_bytree': 0.7316852362415537, 'subsample_freq': 6, 'reg_alpha': 0.16902412885109916, 'reg_lambda': 0.005860501693795806, 'learning_rate': 0.19161220072081311, 'n_estimators': 249, 'min_split_gain': 0.17775042376627787, 'min_data_in_leaf': 33}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:58:18,383] Trial 17 finished with value: 14.420601482943985 and parameters: {'num_leaves': 53, 'max_depth': 12, 'min_child_samples': 74, 'min_child_weight': 0.0037963762166758476, 'subsample': 0.7590602526122234, 'colsample_bytree': 0.7780776985656972, 'subsample_freq': 4, 'reg_alpha': 8.80207501426475, 'reg_lambda': 1.0135663854176074e-08, 'learning_rate': 0.04837329534357245, 'n_estimators': 168, 'min_split_gain': 0.29873586615997055, 'min_data_in_leaf': 19}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 18:59:51,678] Trial 18 finished with value: 14.006825236643607 and parameters: {'num_leaves': 205, 'max_depth': 10, 'min_child_samples': 97, 'min_child_weight': 0.07572849695261563, 'subsample': 0.9449923596722283, 'colsample_bytree': 0.7156373773583791, 'subsample_freq': 4, 'reg_alpha': 8.186878512095412e-07, 'reg_lambda': 0.00013614029187288904, 'learning_rate': 0.0808020545700179, 'n_estimators': 195, 'min_split_gain': 0.6212904036835193, 'min_data_in_leaf': 15}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 19:01:08,477] Trial 19 finished with value: 13.905391076374135 and parameters: {'num_leaves': 42, 'max_depth': 10, 'min_child_samples': 69, 'min_child_weight': 0.011872681218284513, 'subsample': 0.8648738294126247, 'colsample_bytree': 0.8815320376031495, 'subsample_freq': 6, 'reg_alpha': 0.00014144604283550518, 'reg_lambda': 1.2830268176152784e-06, 'learning_rate': 0.21159245128370585, 'n_estimators': 221, 'min_split_gain': 0.10452618878009802, 'min_data_in_leaf': 32}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 19:02:25,655] Trial 20 finished with value: 14.003868624678297 and parameters: {'num_leaves': 40, 'max_depth': 10, 'min_child_samples': 70, 'min_child_weight': 0.4956616365793596, 'subsample': 0.8608775194487167, 'colsample_bytree': 0.9077175759427999, 'subsample_freq': 6, 'reg_alpha': 9.859231500825007e-05, 'reg_lambda': 7.036808790671e-07, 'learning_rate': 0.1192256601486948, 'n_estimators': 223, 'min_split_gain': 0.10246530288789775, 'min_data_in_leaf': 32}. Best is trial 9 with value: 13.876688119185703.
# [I 2025-08-27 19:04:11,213] Trial 21 finished with value: 13.802479965098804 and parameters: {'num_leaves': 95, 'max_depth': 11, 'min_child_samples': 49, 'min_child_weight': 0.014025844684536503, 'subsample': 0.9249201521921242, 'colsample_bytree': 0.8660698517703787, 'subsample_freq': 6, 'reg_alpha': 0.027908025104943317, 'reg_lambda': 2.5866769278042603e-06, 'learning_rate': 0.2077560008369304, 'n_estimators': 259, 'min_split_gain': 0.10492489288915806, 'min_data_in_leaf': 35}. Best is trial 21 with value: 13.802479965098804.
# [I 2025-08-27 19:05:58,627] Trial 22 finished with value: 13.800622278753833 and parameters: {'num_leaves': 91, 'max_depth': 11, 'min_child_samples': 50, 'min_child_weight': 0.005613593714732288, 'subsample': 0.8706942116163565, 'colsample_bytree': 0.892310156519999, 'subsample_freq': 6, 'reg_alpha': 3.8072099139367135e-07, 'reg_lambda': 5.368843345193766e-05, 'learning_rate': 0.23421523553817178, 'n_estimators': 272, 'min_split_gain': 0.08887437710453637, 'min_data_in_leaf': 32}. Best is trial 22 with value: 13.800622278753833.
# [I 2025-08-27 19:07:45,715] Trial 23 finished with value: 13.787356151207426 and parameters: {'num_leaves': 96, 'max_depth': 11, 'min_child_samples': 46, 'min_child_weight': 0.004314290308759151, 'subsample': 0.9009026404822346, 'colsample_bytree': 0.8465815606374963, 'subsample_freq': 6, 'reg_alpha': 1.2649825849245461e-07, 'reg_lambda': 9.315635922604563e-05, 'learning_rate': 0.23157585403052275, 'n_estimators': 270, 'min_split_gain': 0.0034216270099568097, 'min_data_in_leaf': 22}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:08:44,637] Trial 24 finished with value: 13.88256636146311 and parameters: {'num_leaves': 103, 'max_depth': 11, 'min_child_samples': 47, 'min_child_weight': 0.004613455566557724, 'subsample': 0.8208660874633481, 'colsample_bytree': 0.9438999593061375, 'subsample_freq': 6, 'reg_alpha': 6.406756321369742e-08, 'reg_lambda': 0.0007616776168097373, 'learning_rate': 0.23690603113200662, 'n_estimators': 278, 'min_split_gain': 0.28032073994776474, 'min_data_in_leaf': 20}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:10:16,977] Trial 25 finished with value: 13.886988124173874 and parameters: {'num_leaves': 144, 'max_depth': 12, 'min_child_samples': 39, 'min_child_weight': 0.004460203204953551, 'subsample': 0.8852927655497332, 'colsample_bytree': 0.8407187389819892, 'subsample_freq': 6, 'reg_alpha': 1.0585968863393107e-07, 'reg_lambda': 3.0042578230810294e-05, 'learning_rate': 0.13223241178274764, 'n_estimators': 272, 'min_split_gain': 0.38323674874184693, 'min_data_in_leaf': 22}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:11:25,458] Trial 26 finished with value: 18.286342757797083 and parameters: {'num_leaves': 87, 'max_depth': 9, 'min_child_samples': 51, 'min_child_weight': 0.007059447996035539, 'subsample': 0.7906859389716827, 'colsample_bytree': 0.9166502801559054, 'subsample_freq': 7, 'reg_alpha': 0.02035235919839991, 'reg_lambda': 0.002841683679814475, 'learning_rate': 0.010772994096062007, 'n_estimators': 164, 'min_split_gain': 0.08057830888222357, 'min_data_in_leaf': 36}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:12:36,621] Trial 27 finished with value: 13.877556839110662 and parameters: {'num_leaves': 127, 'max_depth': 9, 'min_child_samples': 27, 'min_child_weight': 0.025429545713808958, 'subsample': 0.8336016709979852, 'colsample_bytree': 0.882953425686364, 'subsample_freq': 5, 'reg_alpha': 1.3949200658866989e-06, 'reg_lambda': 4.15294090221917e-06, 'learning_rate': 0.2448118249206828, 'n_estimators': 256, 'min_split_gain': 0.2556762262746245, 'min_data_in_leaf': 37}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:14:27,045] Trial 28 finished with value: 13.862098900103867 and parameters: {'num_leaves': 94, 'max_depth': 11, 'min_child_samples': 16, 'min_child_weight': 0.002652928185751954, 'subsample': 0.7706764916229043, 'colsample_bytree': 0.9994870700425436, 'subsample_freq': 6, 'reg_alpha': 5.39744240763487e-08, 'reg_lambda': 0.00022605814709644143, 'learning_rate': 0.08745737783144732, 'n_estimators': 282, 'min_split_gain': 0.13630153950098126, 'min_data_in_leaf': 14}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:15:52,553] Trial 29 finished with value: 13.940287661258207 and parameters: {'num_leaves': 125, 'max_depth': 12, 'min_child_samples': 37, 'min_child_weight': 0.060352290810118156, 'subsample': 0.8876519611090149, 'colsample_bytree': 0.81331261594828, 'subsample_freq': 7, 'reg_alpha': 1.0678526883794393, 'reg_lambda': 0.00976193866197463, 'learning_rate': 0.10708222035081805, 'n_estimators': 238, 'min_split_gain': 0.5702496068170416, 'min_data_in_leaf': 30}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:16:28,595] Trial 30 finished with value: 14.044479388252858 and parameters: {'num_leaves': 158, 'max_depth': 11, 'min_child_samples': 48, 'min_child_weight': 0.001039461452518547, 'subsample': 0.9285592614627597, 'colsample_bytree': 0.866181346098268, 'subsample_freq': 4, 'reg_alpha': 2.415149607093752e-05, 'reg_lambda': 2.702902378189528e-05, 'learning_rate': 0.13757450042416716, 'n_estimators': 65, 'min_split_gain': 0.05917604738360716, 'min_data_in_leaf': 21}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:18:17,404] Trial 31 finished with value: 13.866972719253017 and parameters: {'num_leaves': 87, 'max_depth': 11, 'min_child_samples': 19, 'min_child_weight': 0.0027588017249046783, 'subsample': 0.7536745942907813, 'colsample_bytree': 0.995944921321166, 'subsample_freq': 6, 'reg_alpha': 7.303259886365634e-08, 'reg_lambda': 0.0007844350070618241, 'learning_rate': 0.08834653648224834, 'n_estimators': 283, 'min_split_gain': 0.12125689760185444, 'min_data_in_leaf': 12}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:20:16,558] Trial 32 finished with value: 13.90059953619992 and parameters: {'num_leaves': 107, 'max_depth': 12, 'min_child_samples': 17, 'min_child_weight': 0.006453001944340982, 'subsample': 0.7691952213452674, 'colsample_bytree': 0.925232971054538, 'subsample_freq': 6, 'reg_alpha': 3.650487348750835e-07, 'reg_lambda': 0.00018271287227694942, 'learning_rate': 0.0677335355976412, 'n_estimators': 283, 'min_split_gain': 0.15727471759724537, 'min_data_in_leaf': 14}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:21:54,134] Trial 33 finished with value: 14.153229514958744 and parameters: {'num_leaves': 82, 'max_depth': 10, 'min_child_samples': 65, 'min_child_weight': 0.0023248206017334413, 'subsample': 0.675451123557872, 'colsample_bytree': 0.7877590758044397, 'subsample_freq': 5, 'reg_alpha': 3.490655832553199e-08, 'reg_lambda': 7.945236432694391e-05, 'learning_rate': 0.04742612764675405, 'n_estimators': 258, 'min_split_gain': 0.232045639336359, 'min_data_in_leaf': 23}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:22:37,605] Trial 34 finished with value: 13.94220223645775 and parameters: {'num_leaves': 101, 'max_depth': 11, 'min_child_samples': 13, 'min_child_weight': 0.025458239747006846, 'subsample': 0.7250552619391859, 'colsample_bytree': 0.9973928808859744, 'subsample_freq': 6, 'reg_alpha': 1.751098543917216e-07, 'reg_lambda': 0.00036931114600992837, 'learning_rate': 0.2436099630776848, 'n_estimators': 142, 'min_split_gain': 0.40583105001112163, 'min_data_in_leaf': 38}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:24:54,081] Trial 35 finished with value: 14.201868240495317 and parameters: {'num_leaves': 140, 'max_depth': 9, 'min_child_samples': 28, 'min_child_weight': 0.01198478616944173, 'subsample': 0.8532214650111833, 'colsample_bytree': 0.8349729888195799, 'subsample_freq': 7, 'reg_alpha': 2.8517000246986593e-06, 'reg_lambda': 2.2388790003731277e-06, 'learning_rate': 0.020512838370304688, 'n_estimators': 300, 'min_split_gain': 0.0610359583426717, 'min_data_in_leaf': 45}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:26:23,808] Trial 36 finished with value: 13.891496428101046 and parameters: {'num_leaves': 36, 'max_depth': 12, 'min_child_samples': 55, 'min_child_weight': 0.0015463907155072296, 'subsample': 0.8202086683893497, 'colsample_bytree': 0.9401309612170381, 'subsample_freq': 5, 'reg_alpha': 2.6274364803389553e-08, 'reg_lambda': 1.8798918067711854e-05, 'learning_rate': 0.1923949316012481, 'n_estimators': 269, 'min_split_gain': 0.13689967622763854, 'min_data_in_leaf': 6}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:27:08,495] Trial 37 finished with value: 14.155980151436218 and parameters: {'num_leaves': 185, 'max_depth': 7, 'min_child_samples': 33, 'min_child_weight': 0.0030318888113961178, 'subsample': 0.977955289542092, 'colsample_bytree': 0.889341299588318, 'subsample_freq': 6, 'reg_alpha': 0.0004419341221787883, 'reg_lambda': 0.002344838943704682, 'learning_rate': 0.10153325816735723, 'n_estimators': 109, 'min_split_gain': 0.046713126767370675, 'min_data_in_leaf': 17}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:28:39,037] Trial 38 finished with value: 13.831452046433283 and parameters: {'num_leaves': 121, 'max_depth': 10, 'min_child_samples': 61, 'min_child_weight': 0.006467541240107068, 'subsample': 0.7880000142470646, 'colsample_bytree': 0.8581034556698756, 'subsample_freq': 5, 'reg_alpha': 1.066034475599616e-08, 'reg_lambda': 1.0016188512265226e-07, 'learning_rate': 0.14998626406258847, 'n_estimators': 223, 'min_split_gain': 0.13653965627582937, 'min_data_in_leaf': 44}. Best is trial 23 with value: 13.787356151207426.
# [I 2025-08-27 19:29:21,165] Trial 39 finished with value: 14.63464924844108 and parameters: {'num_leaves': 120, 'max_depth': 3, 'min_child_samples': 62, 'min_child_weight': 0.02168289604818605, 'subsample': 0.875282272169964, 'colsample_bytree': 0.8523657517524307, 'subsample_freq': 5, 'reg_alpha': 0.016325333212410684, 'reg_lambda': 5.1415167561051765e-08, 'learning_rate': 0.1463592688996134, 'n_estimators': 213, 'min_split_gain': 0.34655678472254586, 'min_data_in_leaf': 45}. Best is trial 23 with value: 13.787356151207426.
#
# LGB Optimization completed!
#   Best patient-based MAE: 13.7874
#   Best parameters: {'num_leaves': 96, 'max_depth': 11, 'min_child_samples': 46, 'min_child_weight': 0.004314290308759151, 'subsample': 0.9009026404822346, 'colsample_bytree': 0.8465815606374963, 'subsample_freq': 6, 'reg_alpha': 1.2649825849245461e-07, 'reg_lambda': 9.315635922604563e-05, 'learning_rate': 0.23157585403052275, 'n_estimators': 270, 'min_split_gain': 0.0034216270099568097, 'min_data_in_leaf': 22}
#
# ----------------------------------------
# TUNING SUMMARY - LGB
# ----------------------------------------
# Baseline MAE: 14.2872
# Best MAE: 13.7874
# Improvement: 0.4999 (3.50%)
# Best parameters: {'num_leaves': 96, 'max_depth': 11, 'min_child_samples': 46, 'min_child_weight': 0.004314290308759151, 'subsample': 0.9009026404822346, 'colsample_bytree': 0.8465815606374963, 'subsample_freq': 6, 'reg_alpha': 1.2649825849245461e-07, 'reg_lambda': 9.315635922604563e-05, 'learning_rate': 0.23157585403052275, 'n_estimators': 270, 'min_split_gain': 0.0034216270099568097, 'min_data_in_leaf': 22}

# %% [markdown]
# ## Optimization Visualization
# Generate plots showing the optimization history for each model.

# %%
# Generate optimization plots for each model
for model_name, results in tuning_results.items():
    print(f"\nGenerating optimization plots for {model_name.upper()}...")
    plot_optimization_history(results['study'], model_name, config['output_dir'])

    # Display the plot in notebook
    plt.figure(figsize=(15, 5))

    # Plot 1: Optimization History
    plt.subplot(1, 3, 1)
    trials = results['study'].trials
    values = [trial.value for trial in trials if trial.value is not None]
    plt.plot(values, 'b-', alpha=0.7, linewidth=1)
    plt.axhline(y=results['baseline_mae'], color='r', linestyle='--',
                label=f'Baseline: {results["baseline_mae"]:.4f}')
    plt.axhline(y=results['best_mae'], color='g', linestyle='--',
                label=f'Best: {results["best_mae"]:.4f}')
    plt.xlabel('Trial')
    plt.ylabel('MAE')
    plt.title(f'{model_name.upper()} - Optimization History')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Plot 2: Parameter importance
    plt.subplot(1, 3, 2)
    try:
        importances = results['study'].get_trials_dataframe()[
            [col for col in results['study'].get_trials_dataframe().columns
             if col.startswith('params_')]
        ].corrwith(results['study'].get_trials_dataframe()['value']).abs().sort_values(ascending=True)
        importances.plot(kind='barh')
        plt.title(f'{model_name.upper()} - Parameter Correlations')
        plt.xlabel('Absolute Correlation with MAE')
    except:
        plt.text(0.5, 0.5, 'Parameter importance\nnot available',
                ha='center', va='center', transform=plt.gca().transAxes)
        plt.title(f'{model_name.upper()} - Parameter Importance')

    # Plot 3: Best vs Baseline comparison
    plt.subplot(1, 3, 3)
    models = ['Baseline', 'Best']
    maes = [results['baseline_mae'], results['best_mae']]
    colors = ['red', 'green']
    bars = plt.bar(models, maes, color=colors, alpha=0.7)
    plt.ylabel('MAE')
    plt.title(f'{model_name.upper()} - Comparison')

    # Add value labels on bars
    for bar, mae in zip(bars, maes):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
                f'{mae:.4f}', ha='center', va='bottom')

    plt.tight_layout()
    plt.show()
# Out:
# Generating optimization plots for LGB...
# Generating optimization plots for LGB...
# Optimization plots saved to: tuning/results/lgb_optimization_analysis.png
# Parameter importance saved to: tuning/results/lgb_parameter_importance.csv

# %% [markdown]
# ## Final Model Training and Evaluation
# Train final models with best parameters and evaluate on test set.

# %%
# Train final models and evaluate on test set
final_results = {}

for model_name, results in tuning_results.items():
    print(f"\n{'='*50}")
    print(f"FINAL MODEL TRAINING - {model_name.upper()}")
    print(f"{'='*50}")

    # Combine base parameters with best trial parameters
    best_params = {**results['base_params'], **results['best_params']}

    print(f"Training final model with optimized parameters...")
    print(f"Best parameters: {results['best_params']}")

    # Train final model and evaluate
    final_model, test_results, test_mae = train_final_model_and_evaluate(
        results['model_class'],
        best_params,
        train_set,
        val_set,
        test_set,
        X_cols,
        y_cols,
        config['output_dir'],
        model_name,
    )

    final_results[model_name] = {
        'model': final_model,
        'test_results': test_results,
        'test_mae': test_mae,
        'val_mae': results['best_mae'],
        'baseline_mae': results['baseline_mae']
    }

    improvement = results['baseline_mae'] - results['best_mae']
    improvement_pct = (improvement / results['baseline_mae'] * 100)

    print(f"\nResults for {model_name.upper()}:")
    print(f"  Validation MAE (best trial): {results['best_mae']:.4f}")
    print(f"  Test MAE (final model): {test_mae:.4f}")
    print(f"  Improvement over baseline: {improvement:.4f} ({improvement_pct:.2f}%)")
    print(f"  Model saved to: {config['output_dir']}/{model_name}_best_model.pickle")
    print(f"  Results saved to: {config['output_dir']}/{model_name}_test_results.csv")
# Out:
# ==================================================
# FINAL MODEL TRAINING - LGB
# ==================================================
# Training final model with optimized parameters...
# Best parameters: {'num_leaves': 96, 'max_depth': 11, 'min_child_samples': 46, 'min_child_weight': 0.004314290308759151, 'subsample': 0.9009026404822346, 'colsample_bytree': 0.8465815606374963, 'subsample_freq': 6, 'reg_alpha': 1.2649825849245461e-07, 'reg_lambda': 9.315635922604563e-05, 'learning_rate': 0.23157585403052275, 'n_estimators': 270, 'min_split_gain': 0.0034216270099568097, 'min_data_in_leaf': 22}
#
# ============================================================
# FINAL MODEL TRAINING AND EVALUATION - LGB
# ============================================================
# Combined train+val set size: 15919402
# Test set size: 3945594
#
# Training final LGB model with best parameters...
# Best parameters: {'objective': 'regression', 'metric': 'mae', 'random_state': 42, 'verbosity': -1, 'force_row_wise': True, 'device': 'gpu', 'gpu_use_dp': False, 'num_leaves': 96, 'max_depth': 11, 'min_child_samples': 46, 'min_child_weight': 0.004314290308759151, 'subsample': 0.9009026404822346, 'colsample_bytree': 0.8465815606374963, 'subsample_freq': 6, 'reg_alpha': 1.2649825849245461e-07, 'reg_lambda': 9.315635922604563e-05, 'learning_rate': 0.23157585403052275, 'n_estimators': 270, 'min_split_gain': 0.0034216270099568097, 'min_data_in_leaf': 22}
# Final model saved to: tuning/results/lgb_best_model.pickle
#
# Evaluating on test set...
# Cumulative
# Samples: 3945594
# MAE: 13.47(2.11)
# MAPE: 9.38(1.49)
# RMSE: 18.65(2.94)
# ~~~~~~~~~~
# Normal
# Samples: 2518655
# MAE: 12.17(1.87)
# MAPE: 9.95(1.59)
# RMSE: 16.96(2.61)
# ~~~~~~~~~~
# Hyper
# Samples: 1246879
# MAE: 15.95(2.46)
# MAPE: 7.00(1.04)
# RMSE: 21.64(3.24)
# ~~~~~~~~~~
# Hypo
# Samples: 180060
# MAE: 13.98(3.38)
# MAPE: 23.34(5.71)
# RMSE: 17.47(4.27)
# Test results saved to: tuning/results/lgb_test_results.csv
#
# Final test MAE: 13.4708
#
# Results for LGB:
#   Validation MAE (best trial): 13.7874
#   Test MAE (final model): 13.4708
#   Improvement over baseline: 0.4999 (3.50%)
#   Model saved to: tuning/results/lgb_best_model.pickle
#   Results saved to: tuning/results/lgb_test_results.csv

# %% [markdown]
# ## Results Summary and Comparison
# Compare the performance of all tuned models.

# %%
# Create summary table
summary_data = []
for model_name, results in final_results.items():
    baseline_mae = results['baseline_mae']
    val_mae = results['val_mae']
    test_mae = results['test_mae']
    improvement = baseline_mae - val_mae
    improvement_pct = (improvement / baseline_mae * 100)

    summary_data.append({
        'Model': model_name.upper(),
        'Baseline MAE': f"{baseline_mae:.4f}",
        'Best Val MAE': f"{val_mae:.4f}",
        'Test MAE': f"{test_mae:.4f}",
        'Improvement': f"{improvement:.4f}",
        'Improvement (%)': f"{improvement_pct:.2f}%"
    })

summary_df = pd.DataFrame(summary_data)

print(f"\n{'='*80}")
print("FINAL TUNING SUMMARY")
print(f"{'='*80}")
print(summary_df.to_string(index=False))

# Save summary
summary_df.to_csv(f"{config['output_dir']}/tuning_summary.csv", index=False)
print(f"\nSummary saved to: {config['output_dir']}/tuning_summary.csv")
# Out:
# ================================================================================
# FINAL TUNING SUMMARY
# ================================================================================
# Model Baseline MAE Best Val MAE Test MAE Improvement Improvement (%)
#   LGB      14.2872      13.7874  13.4708      0.4999           3.50%
#
# Summary saved to: tuning/results/tuning_summary.csv

# %%
# Visual comparison
plt.figure(figsize=(12, 8))

# Extract data for plotting
models = list(final_results.keys())
baseline_maes = [final_results[m]['baseline_mae'] for m in models]
val_maes = [final_results[m]['val_mae'] for m in models]
test_maes = [final_results[m]['test_mae'] for m in models]

x = np.arange(len(models))
width = 0.25

# Create grouped bar chart
plt.subplot(2, 2, 1)
plt.bar(x - width, baseline_maes, width, label='Baseline', alpha=0.8, color='red')
plt.bar(x, val_maes, width, label='Best Validation', alpha=0.8, color='green')
plt.bar(x + width, test_maes, width, label='Test', alpha=0.8, color='blue')

plt.xlabel('Models')
plt.ylabel('MAE')
plt.title('Model Performance Comparison')
plt.xticks(x, [m.upper() for m in models])
plt.legend()
plt.grid(True, alpha=0.3)

# Improvement percentages
plt.subplot(2, 2, 2)
improvements = [(baseline_maes[i] - val_maes[i]) / baseline_maes[i] * 100
                for i in range(len(models))]
colors = ['green' if imp > 0 else 'red' for imp in improvements]
bars = plt.bar([m.upper() for m in models], improvements, color=colors, alpha=0.7)
plt.ylabel('Improvement (%)')
plt.title('Improvement over Baseline')
plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)

# Add value labels
for bar, imp in zip(bars, improvements):
    plt.text(bar.get_x() + bar.get_width()/2,
             bar.get_height() + (0.05 if imp > 0 else -0.1),
             f'{imp:.2f}%', ha='center', va='bottom' if imp > 0 else 'top')

# Best parameters comparison
plt.subplot(2, 1, 2)
plt.text(0.1, 0.9, 'Best Hyperparameters:', fontsize=14, fontweight='bold',
         transform=plt.gca().transAxes)
y_pos = 0.8
for model_name in models:
    params = tuning_results[model_name]['best_params']
    plt.text(0.1, y_pos, f"{model_name.upper()}:", fontweight='bold',
             transform=plt.gca().transAxes)
    y_pos -= 0.1
    for param, value in params.items():
        plt.text(0.15, y_pos, f"  {param}: {value}",
                transform=plt.gca().transAxes)
        y_pos -= 0.05
    y_pos -= 0.05

plt.axis('off')
plt.tight_layout()
plt.savefig(f"{config['output_dir']}/tuning_summary_plots.png", dpi=300, bbox_inches='tight')
plt.show()

print(f"\nAll tuning results saved to: {config['output_dir']}")
print("\nTuning process completed successfully!")
# Out:
# All tuning results saved to: tuning/results
#
# Tuning process completed successfully!

# %%
from google.colab import runtime
runtime.unassign()
